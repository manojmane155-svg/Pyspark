# %%
# Open the file in read mode and obtain a file handler
with open('new_task_1.txt', 'r') as file_handler:
# Read one line at a time
    line = file_handler.readline()
    while line:
# Process the line
        print(line.strip()) # strip() to remove leading and trailing whitespace
# Read the next line
        line = file_handler.readline()
# Out:
# This is a new file
# This is appended content

# %%
# Open the file in read mode and obtain a file handler
with open('new_task_1.txt', 'r') as file_handler:
    # Read all lines into a list
    lines = file_handler.readlines()
# Iterate over the lines
    for line in lines:
# Process each line
        print(line.strip()) # strip() to remove leading and trailing whitespace
# Out:
# This is a new file
# This is appended content

# %%
# Open the file in read mode and obtain a file handler
with open('new_task_1.txt', 'r') as file_handler:
# Iterate over the file object
    for line in file_handler:
# Process each line
        print(line.strip()) # strip() to remove leading and trailing whitespace
# Out:
# This is a new file
# This is appended content

# %%
# Open the file in write mode and obtain a file handler
with open('new_task_2.txt', 'w') as file_handler:
# Write a line to the file
    file_handler.write("This is a line written to the file.\n")

# %%
try:
    result = 10 / 0 # Attempting division by zero
except ZeroDivisionError:
    print("Error: Division by zero")
# Out:
# Error: Division by zero

# %%
try:
# Code that may raise an exception
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print("Result:", result)
except ValueError:
# Handle ValueError (e.g., invalid input)
    print("Please enter valid integers.")
except ZeroDivisionError:
# Handle ZeroDivisionError (e.g., division by zero)
    print("Error: Division by zero is not allowed.")
except Exception as e:
# Handle any other type of exception
    print("An error occurred:", e)
# Out:
# Enter a number:  10
# Enter another number:  5
# Result: 2.0

# %%
try:
# Code that may raise an exception
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
except ValueError:
# Handle ValueError (e.g., invalid input)
    print("Please enter valid integers.")
except ZeroDivisionError:
# Handle ZeroDivisionError (e.g., division by zero)
    print("Error: Division by zero is not allowed.")
else:
# Code to execute if no exception occurs
    print("Result:", result)
# Out:
# Enter a number:  4
# Enter another number:  2
# Result: 2.0

# %%
try:
# Open a file
    file_handler = open('new_task_2.txt', 'r')
# Read data from the file
    data = file_handler.read()
    print("Data from file:", data)
except FileNotFoundError:
    print("File not found.")
finally:
# Close the file (cleanup action)
    file_handler.close()
    print("File closed.")
# Out:
# Data from file: This is a line written to the file.
#
# File closed.

# %%
import unittest
def add(x, y):
    return x + y
class TestAddFunction(unittest.TestCase):
    def test_add_positive_numbers(self):
        self.assertEqual(add(2, 3), 5)
    def test_add_negative_numbers(self):
        self.assertEqual(add(-2, -3), -5)
if __name__ == '__main__':
    unittest.main()
# Out:
# E
# ======================================================================
# ERROR: C:\Users\MANOJ\AppData\Roaming\jupyter\runtime\kernel-730ce1ae-d59c-42c9-84c5-378296db96d3 (unittest.loader._FailedTest.C:\Users\MANOJ\AppData\Roaming\jupyter\runtime\kernel-730ce1ae-d59c-42c9-84c5-378296db96d3)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\MANOJ\AppData\Roaming\jupyter\runtime\kernel-730ce1ae-d59c-42c9-84c5-378296db96d3'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
