# %%
sales_total = df.groupBy("retailer_id").sum("amount").withColumnRenamed("sum(amount)", "total_sales")

# %%
from pyspark.sql.types import DoubleType

df = df.withColumn("amount", df["amount"].cast(DoubleType()))

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-25.0.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Downloading pyarrow-25.0.0-cp313-cp313-win_amd64.whl (27.9 MB)
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    --- ------------------------------------ 2.6/27.9 MB 15.2 MB/s eta 0:00:02
#    ------ --------------------------------- 4.5/27.9 MB 11.1 MB/s eta 0:00:03
#    -------- ------------------------------- 5.8/27.9 MB 9.5 MB/s eta 0:00:03
#    --------- ------------------------------ 6.8/27.9 MB 8.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 7.9/27.9 MB 7.6 MB/s eta 0:00:03
#    ------------ --------------------------- 8.4/27.9 MB 6.9 MB/s eta 0:00:03
#    ------------ --------------------------- 8.7/27.9 MB 6.2 MB/s eta 0:00:04
#    ------------ --------------------------- 8.9/27.9 MB 5.3 MB/s eta 0:00:04
#    ------------ --------------------------- 8.9/27.9 MB 5.3 MB/s eta 0:00:04
#    ------------- -------------------------- 9.4/27.9 MB 4.4 MB/s eta 0:00:05
#    ------------- -------------------------- 9.7/27.9 MB 4.2 MB/s eta 0:00:05
#    -------------- ------------------------- 10.2/27.9 MB 4.0 MB/s eta 0:00:05
#    --------------- ------------------------ 10.5/27.9 MB 3.9 MB/s eta 0:00:05
#    --------------- ------------------------ 11.0/27.9 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.3/27.9 MB 3.6 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.8/27.9 MB 3.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.3/27.9 MB 3.4 MB/s eta 0:00:05
#    ------------------ --------------------- 12.8/27.9 MB 3.4 MB/s eta 0:00:05
#    ------------------- -------------------- 13.6/27.9 MB 3.3 MB/s eta 0:00:05
#    -------------------- ------------------- 14.4/27.9 MB 3.4 MB/s eta 0:00:05
#    --------------------- ------------------ 15.2/27.9 MB 3.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.3/27.9 MB 3.4 MB/s eta 0:00:04
#    ------------------------ --------------- 17.3/27.9 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 18.4/27.9 MB 3.5 MB/s eta 0:00:03
#    --------------------------- ------------ 19.4/27.9 MB 3.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.7/27.9 MB 3.7 MB/s eta 0:00:02
#    ------------------------------- -------- 21.8/27.9 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 23.3/27.9 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.1/27.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 25.4/27.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 26.5/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  27.5/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 27.9/27.9 MB 3.5 MB/s  0:00:08
# Installing collected packages: pyarrow
# Successfully installed pyarrow-25.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2026.5.0-cp313-cp313-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas>=1.5.0 in C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastparquet) (3.0.3)
# Requirement already satisfied: numpy in C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastparquet) (2.4.6)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl.metadata (681 bytes)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2026.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastparquet) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.5.0->fastparquet) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\MANOJ\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading fastparquet-2026.5.0-cp313-cp313-win_amd64.whl (695 kB)
#    ---------------------------------------- 0.0/695.2 kB ? eta -:--:--
#    ----------------------------- --------- 524.3/695.2 kB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 695.2/695.2 kB 3.2 MB/s  0:00:00
# Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 8.8 MB/s  0:00:00
# Downloading fsspec-2026.6.0-py3-none-any.whl (203 kB)
# Installing collected packages: fsspec, cramjam, fastparquet
#
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ------------- -------------------------- 1/3 [cramjam]
#    ------------- -------------------------- 1/3 [cramjam]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
#    ---------------------------------------- 3/3 [fastparquet]
#
# Successfully installed cramjam-2.11.0 fastparquet-2026.5.0 fsspec-2026.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
df_parquet = spark.read.parquet("C:/JupyterDemo/Pyspark/mtcars.parquet")
df_parquet.show()
# Out:
# +-------------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |              model| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-------------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |          Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|
# |      Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|
# |         Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|
# |     Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|
# |  Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|
# |            Valiant|18.1|  6|225.0|105|2.76| 3.46|20.22|  1|  0|   3|   1|
# |         Duster 360|14.3|  8|360.0|245|3.21| 3.57|15.84|  0|  0|   3|   4|
# |          Merc 240D|24.4|  4|146.7| 62|3.69| 3.19| 20.0|  1|  0|   4|   2|
# |           Merc 230|22.8|  4|140.8| 95|3.92| 3.15| 22.9|  1|  0|   4|   2|
# |           Merc 280|19.2|  6|167.6|123|3.92| 3.44| 18.3|  1|  0|   4|   4|
# |          Merc 280C|17.8|  6|167.6|123|3.92| 3.44| 18.9|  1|  0|   4|   4|
# |         Merc 450SE|16.4|  8|275.8|180|3.07| 4.07| 17.4|  0|  0|   3|   3|
# |         Merc 450SL|17.3|  8|275.8|180|3.07| 3.73| 17.6|  0|  0|   3|   3|
# |        Merc 450SLC|15.2|  8|275.8|180|3.07| 3.78| 18.0|  0|  0|   3|   3|
# | Cadillac Fleetwood|10.4|  8|472.0|205|2.93| 5.25|17.98|  0|  0|   3|   4|
# |Lincoln Continental|10.4|  8|460.0|215| 3.0|5.424|17.82|  0|  0|   3|   4|
# |  Chrysler Imperial|14.7|  8|440.0|230|3.23|5.345|17.42|  0|  0|   3|   4|
# |           Fiat 128|32.4|  4| 78.7| 66|4.08|  2.2|19.47|  1|  1|   4|   1|
# |        Honda Civic|30.4|  4| 75.7| 52|4.93|1.615|18.52|  1|  1|   4|   2|
# |     Toyota Corolla|33.9|  4| 71.1| 65|4.22|1.835| 19.9|  1|  1|   4|   1|
# +-------------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 20 rows

# %%
df_parquet.printSchema()
# Out:
# root
#  |-- model: string (nullable = true)
#  |-- mpg: double (nullable = true)
#  |-- cyl: integer (nullable = true)
#  |-- disp: double (nullable = true)
#  |-- hp: integer (nullable = true)
#  |-- drat: double (nullable = true)
#  |-- wt: double (nullable = true)
#  |-- qsec: double (nullable = true)
#  |-- vs: integer (nullable = true)
#  |-- am: integer (nullable = true)
#  |-- gear: integer (nullable = true)
#  |-- carb: integer (nullable = true)

# %%
df_orc = spark.read.orc("C:/JupyterDemo/Pyspark/orc_metadata_sample.orc")
df_orc.show()
# Out:
# +--------+-----+------+----+-----------+------+-------+------+-------+------+----+----+
# |boolean1|byte1|short1|int1|      long1|float1|double1|bytes1|string1|middle|list| map|
# +--------+-----+------+----+-----------+------+-------+------+-------+------+----+----+
# |    true|  127|  1024|  42|45097156608|3.1415| -2.713|  NULL|   NULL|  NULL|NULL|NULL|
# +--------+-----+------+----+-----------+------+-------+------+-------+------+----+----+

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("AvroExample").config("spark.jars.packages", "org.apache.spark:spark-avro_2.12:3.5.0").getOrCreate()

# %%
print(spark.version)
# Out:
# 4.1.2

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("AvroExample").config("spark.jars.packages", "org.apache.spark:spark-avro_2.12:4.1.2").getOrCreate()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("AvroExample").config("spark.jars.packages", "org.apache.spark:spark-avro_2.12:4.1.2").getOrCreate()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("AvroExample").config("spark.jars.packages", "org.apache.spark:spark-avro_2.12:4.1.2").getOrCreate()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("AvroExample").config("spark.jars.packages", "org.apache.spark:spark-avro_2.12:4.1.2").getOrCreate()

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("CheckSpark").getOrCreate()
print(spark.version)
# Out:
# 4.1.2

# %%
import time
def get_time(func):
    def inner_get_time() -> str:
        start_time=time.time()
        func()
        end_time=time.time()
        return (f"Execution time: {(end_time - start_time)*1000} ms")
        print(inner_get_time())

# %%
@get_time
def x():
    df_parquet = spark.read.parquet("C:/JupyterDemo/Pyspark/mtcars.parquet")
df_parquet.count()
# Out:
# 32

# %%
def is_even(number):
    return number % 2 == 0
print(is_even(4)) # True
print(is_even(5)) # False
# Out:
# True
# False

# %%
name = "Vihaan"
age = 2.5
greeting = "Hello, %s! You are %d years old." % (name, age)
print(greeting)
# Out:
# Hello, Vihaan! You are 2 years old.

# %%
name = "Vihaan"
age = 2.5
greeting = "Hello, {}! You are {} years old.".format(name, age)
print(greeting)
# Out:
# Hello, Vihaan! You are 2.5 years old.

# %%
name = "Vihaan"
age = 2.5
greeting = f"Hello, {name}! You are {age} years old."
print(greeting)
# Out:
# Hello, Vihaan! You are 2.5 years old.

# %%
print("Hello\rWorld")
# Out:
# World

# %%
# Create integer variables
x = 5
y = 3
# Perform arithmetic operations
sum_result = x + y
difference_result = x - y
product_result = x * y
quotient_result = x / y # Division returns a float in Python 3.x
floor_division_result = x // y # Floor division returns an integer
remainder_result = x % y # Modulus operator returns the remainder
# Print the results
print("Sum:", sum_result)
print("Difference:", difference_result)
print("Product:", product_result)
print("Quotient:", quotient_result)
print("Floor Division:", floor_division_result)
print("Remainder:", remainder_result)
# Out:
# Sum: 8
# Difference: 2
# Product: 15
# Quotient: 1.6666666666666667
# Floor Division: 1
# Remainder: 2

# %%
# Create floating-point variables
x = 3.5
y = 2.0
# Perform arithmetic operations
sum_result = x + y
difference_result = x - y
product_result = x * y
quotient_result = x / y

# Print the results
print("Sum:", sum_result)
print("Difference:", difference_result)
print("Product:", product_result)
print("Quotient:", quotient_result)
# Out:
# Sum: 5.5
# Difference: 1.5
# Product: 7.0
# Quotient: 1.75

# %%
# Tuple unpacking
x, y, z = 10, 20, 30
print("x:", x) # Output: 10
print("y:", y) # Output: 20
print("z:", z) # Output: 30
# Out:
# x: 10
# y: 20
# z: 30

# %%
# List unpacking
[a, b, c] = [10, 20, 30]
print("a:", a) # Output: 10
print("b:", b) # Output: 20
print("c:", c) # Output: 30
# Out:
# a: 10
# b: 20
# c: 30

# %%
# Extended unpacking
first, *rest = [1, 2, 3, 4, 5]
print("first:", first) # Output: 1
print("rest:", rest) # Output: [2, 3, 4, 5]
# Out:
# first: 1
# rest: [2, 3, 4, 5]

# %%
# Swapping variables
x = 10
y = 20
x, y = y, x
print("x:", x) # Output: 20
print("y:", y) # Output: 10
# Out:
# x: 20
# y: 10

# %%
# Creating a list
my_list = [1, 2, 3, 4, 5]
# Accessing elements of the list
print(my_list[0]) # Output: 1
print(my_list[2]) # Output: 3
# Modifying elements of the list
my_list[1] = 10
print(my_list) # Output: [1, 10, 3, 4, 5]
# Adding elements to the list
my_list.append(6)
print(my_list) # Output: [1, 10, 3, 4, 5, 6]
# Removing elements from the list
my_list.remove(3)
print(my_list) # Output: [1, 10, 4, 5, 6]
# Out:
# 1
# 3
# [1, 10, 3, 4, 5]
# [1, 10, 3, 4, 5, 6]
# [1, 10, 4, 5, 6]

# %%
# Define a list
my_list = ['apple', 'banana', 'cherry', 'date', 'elderberry']
# Access elements by index
print(my_list[0]) # Output: 'apple' (first element)
print(my_list[2]) # Output: 'cherry' (third element)
print(my_list[-1]) # Output: 'elderberry' (last element)
print(my_list[-2]) # Output: 'date' (second-to-last element)
# Out:
# apple
# cherry
# elderberry
# date

# %%
# Define a list
my_list = ['apple', 'banana', 'cherry', 'date', 'elderberry']
# Modify elements in the list
my_list[1] = 'blueberry' # Modify the element at index 1
my_list[-2] = 'grape' # Modify the second-to-last element
# Print the modified list
print(my_list) # Output: ['apple', 'blueberry', 'cherry', 'grape', 'elderberry']
# Out:
# ['apple', 'blueberry', 'cherry', 'grape', 'elderberry']

# %%
# Define a list
my_list = ['apple', 'banana', 'cherry']
# Insert a single element at a specified index
my_list.insert(1, 'blueberry') # Insert 'blueberry' at index 1
# Print the modified list
print(my_list) # Output: ['apple', 'blueberry', 'banana', 'cherry']
# Out:
# ['apple', 'blueberry', 'banana', 'cherry']

# %%
# Define a list
my_list = ['apple', 'banana', 'cherry']
# Create another list of elements to add
new_elements = ['date', 'elderberry']
# Concatenate the two lists to add elements
my_list += new_elements
# Print the modified list
print(my_list) # Output: ['apple', 'banana', 'cherry', 'date', 'elderberry']
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry']

# %%
# Define a list
my_list = ['apple', 'banana', 'cherry', 'date']
# Insert an element in the middle of the list
my_list.insert(2, 'blueberry') # Insert 'blueberry' at index 2
# Print the modified list
print(my_list) # Output: ['apple', 'banana', 'blueberry', 'cherry', 'date']
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'date']

# %%
# Define a list
my_list = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
# Sort the list permanently
my_list.sort()
# Print the sorted list
print("Sorted list:", my_list) # Output: [1, 1, 2, 3, 3, 4, 5, 5, 6, 9]
# Out:
# Sorted list: [1, 1, 2, 3, 3, 4, 5, 5, 6, 9]
