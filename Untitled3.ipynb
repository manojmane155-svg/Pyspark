# %%
# Function definition
def add_numbers(x, y):
# Function body: adds two numbers
    result = x + y
    return result
# Using the function
sum_result = add_numbers(3, 5)
print("Sum:", sum_result)
# Out:
# Sum: 8

# %%
# Function definition
def add_numbers(x, y):
    # Function body: adds two numbers
    result = x + y
    return result

# Using the function
sum_result = add_numbers(3, 5)
print("Sum:", sum_result)
# Out:
# Sum: 8
